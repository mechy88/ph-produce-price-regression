# %% [markdown]
# # Beef Regression Model with SARIMA
# By Menard Gymer V. Rivera

# %% [markdown]
# ## Load the Dataset

# %%
import pandas as pd

# %%
Tilapia_UN = pd.read_excel('./data/beef_UN.xlsx')

# %%
Tilapia_DA = pd.read_excel('./data/beef_DA.xlsx')

# %%
Tilapia_UN
# Out:
#       cm_id               cm_name  um_id um_name  mp_month  mp_year  mp_price
# 0       141  Meat (beef) - Retail      5      KG         5     2020    249.85
# 1       141  Meat (beef) - Retail      5      KG         5     2020    290.00
# 2       141  Meat (beef) - Retail      5      KG         5     2020    296.67
# 3       141  Meat (beef) - Retail      5      KG         5     2020    280.00
# 4       141  Meat (beef) - Retail      5      KG         5     2020    380.00
# ...     ...                   ...    ...     ...       ...      ...       ...
# 1129    141  Meat (beef) - Retail      5      KG         6     2021    337.50
# 1130    141  Meat (beef) - Retail      5      KG         6     2021    345.00
# 1131    141  Meat (beef) - Retail      5      KG         6     2021    386.25
# 1132    141  Meat (beef) - Retail      5      KG         6     2021    272.50
# 1133    141  Meat (beef) - Retail      5      KG         6     2021    318.75
#
# [1134 rows x 7 columns]

# %%
Tilapia_DA.head()
# Out:
#    cm_id               cm_name  um_id um_name  mp_month  mp_year  mp_price
# 0  141.0  Meat (beef) - Retail    5.0      KG         5     2020    220.00
# 1  141.0  Meat (beef) - Retail    5.0      KG         5     2020    220.00
# 2  141.0  Meat (beef) - Retail    5.0      KG         5     2020    233.85
# 3  141.0  Meat (beef) - Retail    5.0      KG         5     2020    234.19
# 4  141.0  Meat (beef) - Retail    5.0      KG         5     2020    240.00

# %% [markdown]
# ## Extract Necessary Columns (Date and Price)

# %% [markdown]
# ### UN World Food Programme

# %%
Tilapia_UN['date'] = pd.to_datetime(
    Tilapia_UN.rename(columns={'mp_year': 'year', 'mp_month': 'month'})[['year', 'month']].assign(day=15)
)

# %%
Tilapia_UN = Tilapia_UN.drop(columns=['cm_id', 'cm_name', 'um_id', 'um_name', 'mp_month', 'mp_year'])

# %%
Tilapia_UN.head()
# Out:
#    mp_price       date
# 0    249.85 2020-05-15
# 1    290.00 2020-05-15
# 2    296.67 2020-05-15
# 3    280.00 2020-05-15
# 4    380.00 2020-05-15

# %% [markdown]
# ### DA Bantay Presyo

# %%
Tilapia_DA['date'] = pd.to_datetime(
    Tilapia_DA.rename(columns={'mp_year': 'year', 'mp_month': 'month'})[['year', 'month']].assign(day=15)
)

# %%
Tilapia_DA = Tilapia_DA.drop(columns=['cm_id', 'cm_name', 'um_id', 'um_name', 'mp_month', 'mp_year'])

# %%
Tilapia_DA.head()
# Out:
#    mp_price       date
# 0    220.00 2020-05-15
# 1    220.00 2020-05-15
# 2    233.85 2020-05-15
# 3    234.19 2020-05-15
# 4    240.00 2020-05-15

# %%
import matplotlib.pyplot as plt

# %%
Tilapia = pd.concat([Tilapia_DA, Tilapia_UN])

# %%
plt.scatter(Tilapia['date'], Tilapia['mp_price'], alpha=0.35)
plt.figure(figsize=(50, 6))
plt.show()

# %%
from datetime import datetime

# %%
# Set Date as the Inex
Tilapia = Tilapia.set_index('date')

# %%
# Aggregate samples to mean
Tilapia = Tilapia.resample('MS').mean()

# %%
Tilapia['mp_price'] = Tilapia['mp_price'].interpolate(method='linear')

# %%
start_date = datetime(2020,1,1)
end_date = datetime(2026,1,1)
lim_tilapia = Tilapia[start_date:end_date]

# %%
plt.figure(figsize=(10,4))
plt.plot(lim_tilapia)
plt.title('Tilapia Price Trend', fontsize=20)
plt.ylabel('Price in Peso', fontsize=16)
plt.ylim(bottom=0)
for year in range(start_date.year,end_date.year):
    plt.axvline(pd.to_datetime(str(year)+'-01-01'), color='k', linestyle='--', alpha=0.2)

# %% [markdown]
# ## Remove the trend

# %%
first_diff = lim_tilapia.diff()[1:]

# %%
plt.figure(figsize=(10,4))
plt.plot(first_diff)
plt.title('Tilapia Price Trend', fontsize=20)
plt.ylabel('Price in Peso', fontsize=16)
for year in range(start_date.year,end_date.year):
    plt.axvline(pd.to_datetime(str(year)+'-01-01'), color='k', linestyle='--', alpha=0.2)
plt.axhline(0, color='k', linestyle='--', alpha=0.2)

# %% [markdown]
# ## ACF

# %%
from statsmodels.tsa.stattools import acf, pacf

# %%
acf_vals = acf(first_diff)
num_lags = 18
plt.bar(range(num_lags), acf_vals[:num_lags])
# Out:
# <BarContainer object of 18 artists>

# %% [markdown]
# ### Based on ACF, we should start with a seasonal MA process

# %% [markdown]
# ## PACF

# %%
pacf_vals = pacf(first_diff)
num_lags = 18
plt.bar(range(num_lags), pacf_vals[:num_lags])
# Out:
# <BarContainer object of 18 artists>

# %% [markdown]
# ### Based on PACF, we should start with a seasonal AR process

# %% [markdown]
# ## Get training and testing sets

# %%
from datetime import timedelta

# %%
train_end = datetime(2024,9,1)
test_end = datetime(2025,3,1)

train_data = lim_tilapia[:train_end]
test_data = lim_tilapia[train_end + timedelta(days=1):test_end]

# %%
Tilapia.describe()
# Out:
#          mp_price
# count   59.000000
# mean   382.365874
# std     37.832055
# min    309.810566
# 25%    350.433046
# 50%    395.475000
# 75%    412.917500
# max    427.145000

# %% [markdown]
# ## Fit the SARIMA Model

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
my_order = (0,1,0)
my_seasonal_order = (1, 0, 1, 12)
# define model
model = SARIMAX(train_data, order=my_order, seasonal_order=my_seasonal_order)

# %%
from time import time

# %%
#fit the model
start = time()
model_fit = model.fit()
end = time()
print('Model Fitting Time:', end - start)
# Out:
# Model Fitting Time: 0.46158552169799805

# %%
#summary of the model
print(model_fit.summary())
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                             mp_price   No. Observations:                   53
# Model:             SARIMAX(0, 1, 0)x(1, 0, [1], 12)   Log Likelihood                -129.167
# Date:                              Wed, 21 May 2025   AIC                            264.334
# Time:                                      08:07:03   BIC                            270.188
# Sample:                                  05-01-2020   HQIC                           266.578
#                                        - 09-01-2024
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L12       0.9632      0.372      2.590      0.010       0.234       1.692
# ma.S.L12      -0.7809      1.094     -0.714      0.475      -2.924       1.363
# sigma2         7.1429      4.842      1.475      0.140      -2.348      16.634
# ===================================================================================
# Ljung-Box (L1) (Q):                  11.31   Jarque-Bera (JB):                 4.26
# Prob(Q):                              0.00   Prob(JB):                         0.12
# Heteroskedasticity (H):               0.24   Skew:                             0.68
# Prob(H) (two-sided):                  0.00   Kurtosis:                         2.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
print(type(test_data))
print(test_data.columns)
print(test_data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index(['mp_price'], dtype='object')
#             mp_price
# date
# 2024-10-01   418.375
# 2024-11-01   421.555
# 2024-12-01   424.745
# 2025-01-01   426.575
# 2025-02-01   427.145

# %%
# Assuming test_data is a DataFrame with a single column named "mp_price"
test_series = test_data['mp_price']

# %%
#get the predictions and residuals
predictions = model_fit.forecast(len(test_data))
predictions = pd.Series(predictions, index=test_data.index)
residuals = test_series - predictions

# %%
predictions
# Out:
# date
# 2024-10-01    419.453036
# 2024-11-01    421.622359
# 2024-12-01    425.228571
# 2025-01-01    426.248580
# 2025-02-01    427.705614
# 2025-03-01    428.734058
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
residuals
# Out:
# date
# 2024-10-01   -1.078036
# 2024-11-01   -0.067359
# 2024-12-01   -0.483571
# 2025-01-01    0.326420
# 2025-02-01   -0.560614
# 2025-03-01   -4.109058
# Freq: MS, dtype: float64

# %%
plt.figure(figsize=(10,4))
plt.plot(residuals)
plt.axhline(0, linestyle='--', color='k')
plt.title('Residuals from SARIMA Model', fontsize=20)
plt.ylabel('Error', fontsize=16)
# Out:
# Text(0, 0.5, 'Error')

# %%
plt.figure(figsize=(10,4))

plt.plot(lim_tilapia)
plt.plot(predictions)

plt.legend(('Data', 'Predictions'), fontsize=16)

plt.title('Tilapia Price Trend', fontsize=20)
plt.ylabel('Price in Peso', fontsize=16)
for year in range(start_date.year,end_date.year):
    plt.axvline(pd.to_datetime(str(year)+'-01-01'), color='k', linestyle='--', alpha=0.2)

# %% [markdown]
# ## Using the Rolling Forecast Origin

# %%
rolling_predictions = test_series.copy()
for train_end in test_series.index:
    train_data = lim_tilapia[:train_end-timedelta(days=1)]
    model = SARIMAX(train_data, order=my_order, seasonal_order=my_seasonal_order)
    model_fit = model.fit()

    pred = model_fit.forecast()
    rolling_predictions[train_end] = pred
# Out:
# /tmp/ipykernel_20308/2554385675.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rolling_predictions[train_end] = pred
# /tmp/ipykernel_20308/2554385675.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rolling_predictions[train_end] = pred
# /tmp/ipykernel_20308/2554385675.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rolling_predictions[train_end] = pred
# /tmp/ipykernel_20308/2554385675.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rolling_predictions[train_end] = pred
# /tmp/ipykernel_20308/2554385675.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rolling_predictions[train_end] = pred
# /tmp/ipykernel_20308/2554385675.py:8: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rolling_predictions[train_end] = pred

# %%
rolling_residuals = test_series - rolling_predictions

# %%
plt.figure(figsize=(10,4))
plt.plot(rolling_residuals)
plt.axhline(0, linestyle='--', color='k')
plt.title('Rolling Forecast Residuals from SARIMA Model', fontsize=20)
plt.ylabel('Error', fontsize=16)
# Out:
# Text(0, 0.5, 'Error')

# %%
plt.figure(figsize=(10,4))

plt.plot(lim_tilapia)
plt.plot(rolling_predictions)

plt.legend(('Data', 'Predictions'), fontsize=16)

plt.title('Tilapia Price Trend', fontsize=20)
plt.ylabel('Price in Peso', fontsize=16)
for year in range(start_date.year,end_date.year):
    plt.axvline(pd.to_datetime(str(year)+'-01-01'), color='k', linestyle='--', alpha=0.2)

# %%
import numpy as np

# %%
print('Mean Absolute Percent Error:', round(np.mean(abs(rolling_residuals/test_series)),4))
# Out:
# Mean Absolute Percent Error: 0.0032

# %%
print('Root Mean Squared Error:', np.sqrt(np.mean(rolling_residuals**2)))
# Out:
# Root Mean Squared Error: 1.6877489863854767

# %% [markdown]
# ## Future Predictions (2025)

# %%
#get the predictions and residuals
predictions = model_fit.forecast(12)
# predictions = pd.Series(predictions, index=test_data.index)
residuals = test_series - predictions

# %%
predictions
# Out:
# 2025-03-01    428.184439
# 2025-04-01    429.564711
# 2025-05-01    429.801014
# 2025-06-01    430.381779
# 2025-07-01    431.087325
# 2025-08-01    432.391323
# 2025-09-01    434.038948
# 2025-10-01    435.543203
# 2025-11-01    437.866315
# 2025-12-01    441.267606
# 2026-01-01    442.418149
# 2026-02-01    443.633859
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
residuals
# Out:
# 2024-10-01         NaN
# 2024-11-01         NaN
# 2024-12-01         NaN
# 2025-01-01         NaN
# 2025-02-01         NaN
# 2025-03-01   -3.559439
# 2025-04-01         NaN
# 2025-05-01         NaN
# 2025-06-01         NaN
# 2025-07-01         NaN
# 2025-08-01         NaN
# 2025-09-01         NaN
# 2025-10-01         NaN
# 2025-11-01         NaN
# 2025-12-01         NaN
# 2026-01-01         NaN
# 2026-02-01         NaN
# Freq: MS, dtype: float64

# %%
plt.figure(figsize=(10,4))
plt.plot(residuals)
plt.axhline(0, linestyle='--', color='k')
plt.title('Residuals from SARIMA Model', fontsize=20)
plt.ylabel('Error', fontsize=16)
# Out:
# Text(0, 0.5, 'Error')

# %%
plt.figure(figsize=(10,4))

plt.plot(lim_tilapia)
plt.plot(predictions)

plt.legend(('Data', 'Predictions'), fontsize=16)

plt.title('Tilapia Price Trend', fontsize=20)
plt.ylabel('Price in Peso', fontsize=16)
for year in range(2025,2027):
    plt.axvline(pd.to_datetime(str(year)+'-01-01'), color='k', linestyle='--', alpha=0.2)

# %%
# Tilapia 100g
# Protein = 19g
protein = 19*10
# Carbohydrates = 0g
carbs = 0*10
# Fats = 2.48 g
fats = 2.48*10
# Fiber 0g
fiber = 0*10

# %%
protein_projection = protein / predictions

# %%
plt.figure(figsize=(10,4))

plt.plot(protein_projection)

plt.title('Grams of Protein per Peso', fontsize=20)
plt.ylabel('Protein in Grams', fontsize=16)
# Out:
# Text(0, 0.5, 'Protein in Grams')

# %%
carbs_projection = carbs / predictions

# %%
plt.figure(figsize=(10,4))

plt.plot(carbs_projection)

plt.title('Grams of Carbohydrates per Peso', fontsize=20)
plt.ylabel('Protein in Grams', fontsize=16)
# Out:
# Text(0, 0.5, 'Protein in Grams')

# %%
fats_projection = fats / predictions

# %%
plt.figure(figsize=(10,4))

plt.plot(fats_projection)

plt.title('Grams of Fats per Peso', fontsize=20)
plt.ylabel('Protein in Grams', fontsize=16)
# Out:
# Text(0, 0.5, 'Protein in Grams')

# %%
fiber_projection = fiber / predictions

# %%
plt.figure(figsize=(10,4))

plt.plot(fiber_projection)

plt.title('Grams of Fiber per Peso', fontsize=20)
plt.ylabel('Protein in Grams', fontsize=16)
# Out:
# Text(0, 0.5, 'Protein in Grams')

# %%
protein_projection.to_csv('./protein.csv', index=True)
carbs_projection.to_csv('./carbs.csv', index=True)
fats_projection.to_csv('./fats.csv', index=True)
fiber_projection.to_csv('./fiber.csv', index=True)
