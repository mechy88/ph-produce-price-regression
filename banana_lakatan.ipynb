# %% [markdown]
# # Banana Lakatan Regression Model with SARIMA
# By Menard Gymer Rivera

# %% [markdown]
# ## Load the Dataset

# %%
import pandas as pd

# %%
Tilapia_UN = pd.read_excel('./data/banana_lakatan_UN.xlsx')

# %%
Tilapia_DA = pd.read_excel('./data/banana_lakatan_DA.xlsx')

# %%
Tilapia_UN
# Out:
#       cm_id                     cm_name  um_id um_name  mp_month  mp_year  \
# 0       845  Bananas (lakatan) - Retail      5      KG         5     2020
# 1       845  Bananas (lakatan) - Retail      5      KG         5     2020
# 2       845  Bananas (lakatan) - Retail      5      KG         5     2020
# 3       845  Bananas (lakatan) - Retail      5      KG         5     2020
# 4       845  Bananas (lakatan) - Retail      5      KG         5     2020
# ...     ...                         ...    ...     ...       ...      ...
# 1028    845  Bananas (lakatan) - Retail      5      KG         6     2021
# 1029    845  Bananas (lakatan) - Retail      5      KG         6     2021
# 1030    845  Bananas (lakatan) - Retail      5      KG         6     2021
# 1031    845  Bananas (lakatan) - Retail      5      KG         6     2021
# 1032    845  Bananas (lakatan) - Retail      5      KG         6     2021
#
#       mp_price
# 0       104.31
# 1        45.26
# 2        80.00
# 3        87.36
# 4        79.41
# ...        ...
# 1028     71.88
# 1029     80.63
# 1030     87.50
# 1031    106.25
# 1032    101.88
#
# [1033 rows x 7 columns]

# %%
Tilapia_DA.head()
# Out:
#    cm_id                     cm_name  um_id um_name  mp_month  mp_year  \
# 0  845.0  Bananas (lakatan) - Retail    5.0      KG         5     2020
# 1  845.0  Bananas (lakatan) - Retail    5.0      KG         5     2020
# 2  845.0  Bananas (lakatan) - Retail    5.0      KG         5     2020
# 3  845.0  Bananas (lakatan) - Retail    5.0      KG         5     2020
# 4  845.0  Bananas (lakatan) - Retail    5.0      KG         5     2020
#
#    mp_price
# 0    104.31
# 1     45.26
# 2     80.00
# 3     87.36
# 4     79.41

# %% [markdown]
# ## Extract Necessary Columns (Date and Price)

# %% [markdown]
# ### UN World Food Programme

# %%
Tilapia_UN['date'] = pd.to_datetime(
    Tilapia_UN.rename(columns={'mp_year': 'year', 'mp_month': 'month'})[['year', 'month']].assign(day=15)
)

# %%
Tilapia_UN = Tilapia_UN.drop(columns=['cm_id', 'cm_name', 'um_id', 'um_name', 'mp_month', 'mp_year'])

# %%
Tilapia_UN.head()
# Out:
#    mp_price       date
# 0    104.31 2020-05-15
# 1     45.26 2020-05-15
# 2     80.00 2020-05-15
# 3     87.36 2020-05-15
# 4     79.41 2020-05-15

# %% [markdown]
# ### DA Bantay Presyo

# %%
Tilapia_DA['date'] = pd.to_datetime(
    Tilapia_DA.rename(columns={'mp_year': 'year', 'mp_month': 'month'})[['year', 'month']].assign(day=15)
)

# %%
Tilapia_DA = Tilapia_DA.drop(columns=['cm_id','cm_name', 'um_id', 'um_name', 'mp_month', 'mp_year'])

# %%
Tilapia_DA.head()
# Out:
#    mp_price       date
# 0    104.31 2020-05-15
# 1     45.26 2020-05-15
# 2     80.00 2020-05-15
# 3     87.36 2020-05-15
# 4     79.41 2020-05-15

# %%
import matplotlib.pyplot as plt

# %%
Tilapia = pd.concat([Tilapia_DA, Tilapia_UN])

# %%
plt.scatter(Tilapia['date'], Tilapia['mp_price'], alpha=0.35)
plt.figure(figsize=(50, 6))
plt.show()

# %%
from datetime import datetime

# %%
# Set Date as the Inex
Tilapia = Tilapia.set_index('date')

# %%
# Aggregate samples to mean
Tilapia = Tilapia.resample('MS').mean()

# %%
Tilapia['mp_price'] = Tilapia['mp_price'].interpolate(method='linear')

# %%
print("🕓 Index Range:")
print(f"Start: {Tilapia.index.min()}")
print(f"End:   {Tilapia.index.max()}")
print(f"Index type: {type(Tilapia.index)}\n")
# Out:
# 🕓 Index Range:
# Start: 2020-05-01 00:00:00
# End:   2025-03-01 00:00:00
# Index type: <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
start_date = datetime(2020,1,1)
end_date = datetime(2026,1,1)
lim_tilapia = Tilapia[start_date:end_date]

# %%
plt.figure(figsize=(10,4))
plt.plot(lim_tilapia)
plt.title('Tilapia Price Trend', fontsize=20)
plt.ylabel('Price in Peso', fontsize=16)
plt.ylim(bottom=0)
for year in range(start_date.year,end_date.year):
    plt.axvline(pd.to_datetime(str(year)+'-01-01'), color='k', linestyle='--', alpha=0.2)

# %% [markdown]
# ## Remove the trend

# %%
first_diff = lim_tilapia.diff()[1:]

# %%
plt.figure(figsize=(10,4))
plt.plot(first_diff)
plt.title('Tilapia Price Trend', fontsize=20)
plt.ylabel('Price in Peso', fontsize=16)
for year in range(start_date.year,end_date.year):
    plt.axvline(pd.to_datetime(str(year)+'-01-01'), color='k', linestyle='--', alpha=0.2)
plt.axhline(0, color='k', linestyle='--', alpha=0.2)

# %% [markdown]
# ## ACF

# %%
from statsmodels.tsa.stattools import acf, pacf

# %%
first_diff.columns
# Out:
# Index(['mp_price'], dtype='object')

# %%
first_diff.head()
# Out:
#             mp_price
# date
# 2020-06-01 -1.079536
# 2020-07-01 -1.255849
# 2020-08-01 -1.094580
# 2020-09-01 -0.086689
# 2020-10-01 -0.497864

# %%
acf_vals = acf(first_diff)
num_lags = 18
plt.bar(range(num_lags), acf_vals[:num_lags])
# Out:
# <BarContainer object of 18 artists>

# %% [markdown]
# ### Based on ACF, we should start with a seasonal MA process

# %% [markdown]
# ## PACF

# %%
pacf_vals = pacf(first_diff)
num_lags = 18
plt.bar(range(num_lags), pacf_vals[:num_lags])
# Out:
# <BarContainer object of 18 artists>

# %% [markdown]
# ### Based on PACF, we should start with a seasonal AR process

# %% [markdown]
# ## Get training and testing sets

# %%
from datetime import timedelta

# %%
train_end = datetime(2024,9,1)
test_end = datetime(2025,3,1)

train_data = lim_tilapia[:train_end]
test_data = lim_tilapia[train_end + timedelta(days=1):test_end]

# %%
Tilapia.describe()
# Out:
#          mp_price
# count   59.000000
# mean    81.426054
# std     16.204994
# min     64.020000
# 25%     67.719574
# 50%     71.897265
# 75%    101.380000
# max    106.450000

# %% [markdown]
# ## Fit the SARIMA Model

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
my_order = (0,1,0)
my_seasonal_order = (1, 0, 1, 12)
# define model
model = SARIMAX(train_data, order=my_order, seasonal_order=my_seasonal_order)

# %%
from time import time

# %%
#fit the model
start = time()
model_fit = model.fit()
end = time()
print('Model Fitting Time:', end - start)
# Out:
# Model Fitting Time: 0.40869832038879395

# %%
#summary of the model
print(model_fit.summary())
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                             mp_price   No. Observations:                   53
# Model:             SARIMAX(0, 1, 0)x(1, 0, [1], 12)   Log Likelihood                -113.299
# Date:                              Wed, 21 May 2025   AIC                            232.598
# Time:                                      01:35:07   BIC                            238.451
# Sample:                                  05-01-2020   HQIC                           234.842
#                                        - 09-01-2024
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L12       0.4220      0.925      0.456      0.648      -1.391       2.235
# ma.S.L12      -0.1940      0.961     -0.202      0.840      -2.077       1.689
# sigma2         4.5045      0.553      8.139      0.000       3.420       5.589
# ===================================================================================
# Ljung-Box (L1) (Q):                  16.09   Jarque-Bera (JB):                30.42
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               4.89   Skew:                             1.64
# Prob(H) (two-sided):                  0.00   Kurtosis:                         4.82
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
print(type(test_data))
print(test_data.columns)
print(test_data.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index(['mp_price'], dtype='object')
#             mp_price
# date
# 2024-10-01    105.99
# 2024-11-01    105.77
# 2024-12-01    105.81
# 2025-01-01    105.93
# 2025-02-01    104.79

# %%
# Assuming test_data is a DataFrame with a single column named "mp_price"
test_series = test_data['mp_price']

# %%
#get the predictions and residuals
predictions = model_fit.forecast(len(test_data))
predictions = pd.Series(predictions, index=test_data.index)
residuals = test_series - predictions

# %%
predictions
# Out:
# date
# 2024-10-01    107.381674
# 2024-11-01    108.734371
# 2024-12-01    109.473928
# 2025-01-01    110.887659
# 2025-02-01    111.092244
# 2025-03-01    111.720388
# Freq: MS, Name: predicted_mean, dtype: float64

# %%
residuals
# Out:
# date
# 2024-10-01   -1.391674
# 2024-11-01   -2.964371
# 2024-12-01   -3.663928
# 2025-01-01   -4.957659
# 2025-02-01   -6.302244
# 2025-03-01   -5.460388
# Freq: MS, dtype: float64

# %%
plt.figure(figsize=(10,4))
plt.plot(residuals)
plt.axhline(0, linestyle='--', color='k')
plt.title('Residuals from SARIMA Model', fontsize=20)
plt.ylabel('Error', fontsize=16)
# Out:
# Text(0, 0.5, 'Error')

# %%
plt.figure(figsize=(10,4))

plt.plot(lim_tilapia)
plt.plot(predictions)

plt.legend(('Data', 'Predictions'), fontsize=16)

plt.title('Tilapia Price Trend', fontsize=20)
plt.ylabel('Price in Peso', fontsize=16)
for year in range(start_date.year,end_date.year):
    plt.axvline(pd.to_datetime(str(year)+'-01-01'), color='k', linestyle='--', alpha=0.2)

# %% [markdown]
# ## Using the Rolling Forecast Origin

# %%
rolling_predictions = test_series.copy()
for train_end in test_series.index:
    train_data = lim_tilapia[:train_end-timedelta(days=1)]
    model = SARIMAX(train_data['mp_price'], order=my_order, seasonal_order=my_seasonal_order)

    model_fit = model.fit()

    pred = model_fit.forecast()
    rolling_predictions[train_end] = pred
# Out:
# /tmp/ipykernel_60927/2302120164.py:9: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rolling_predictions[train_end] = pred
# /tmp/ipykernel_60927/2302120164.py:9: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rolling_predictions[train_end] = pred
# /tmp/ipykernel_60927/2302120164.py:9: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rolling_predictions[train_end] = pred
# /tmp/ipykernel_60927/2302120164.py:9: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rolling_predictions[train_end] = pred
# /home/meg/jupyter_env/lib/python3.13/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_60927/2302120164.py:9: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rolling_predictions[train_end] = pred
# /tmp/ipykernel_60927/2302120164.py:9: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   rolling_predictions[train_end] = pred

# %%
rolling_residuals = test_series - rolling_predictions

# %%
plt.figure(figsize=(10,4))
plt.plot(rolling_residuals)
plt.axhline(0, linestyle='--', color='k')
plt.title('Rolling Forecast Residuals from SARIMA Model', fontsize=20)
plt.ylabel('Error', fontsize=16)
# Out:
# Text(0, 0.5, 'Error')

# %%
plt.figure(figsize=(10,4))

plt.plot(lim_tilapia)
plt.plot(rolling_predictions)

plt.legend(('Data', 'Predictions'), fontsize=16)

plt.title('Tilapia Price Trend', fontsize=20)
plt.ylabel('Price in Peso', fontsize=16)
for year in range(start_date.year,end_date.year):
    plt.axvline(pd.to_datetime(str(year)+'-01-01'), color='k', linestyle='--', alpha=0.2)

# %%
import numpy as np

# %%
print('Mean Absolute Percent Error:', round(np.mean(abs(rolling_residuals/test_series)),4))
# Out:
# Mean Absolute Percent Error: 0.0105

# %%
print('Root Mean Squared Error:', np.sqrt(np.mean(rolling_residuals**2)))
# Out:
# Root Mean Squared Error: 1.2749832119537492

# %% [markdown]
# ## Future Predictions (2025)

# %% [markdown]
# # eefe
